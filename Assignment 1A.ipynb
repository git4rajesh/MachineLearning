# %% [markdown]
# <a href="https://colab.research.google.com/github/git4rajesh/MachineLearning/blob/master/Assignment%201A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from urllib.request import urlopen
import cv2
from matplotlib import pyplot as plt

# METHOD #1: OpenCV, NumPy, and urllib
def url_to_image(url):
	# download the image, convert it to a NumPy array, and then read
	# it into OpenCV format
	resp = urlopen(url)
	image = np.asarray(bytearray(resp.read()), dtype="uint8")
	image = cv2.imdecode(image, cv2.IMREAD_COLOR)
 
	# return the image
	return image

# %%
image = url_to_image("https://fontsarena-cd5e.kxcdn.com/wp-content/uploads/2019/04/helvetica-now-font-400x364.png")

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(image)

# %%
edges = cv2.Canny(image,100,200)

# %%
cv2_imshow(edges)

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[-1,0,1],[-1,0,1],[-1,0,1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)

# %% [markdown]
# # Horizontal Edge Detector

# %%
# Creating a kernel of 3 * 3 matrix which is a transpose of vertical detector kernel used in example
kernel = np.array([[-1,-1,-1],[0,0,0],[1,1,1]])

# Multiplying the kernel by a factor of 1 to get the Horizontal Edge Detector Kernel
hor_kernel = 1 * (kernel)

# Convolves an image with the kernel. The function applies an arbitrary linear filter to an image
dst = cv2.filter2D(image,-1, hor_kernel)

# Display an image in a window
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F8D42FCCC88>

# %%
# Multiplying the kernel by a factor of 1.5 to get the Horizontal Edge Detector Kernel
hor_kernel = (3/2) * (kernel)
dst = cv2.filter2D(image,-1, hor_kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F8D42FCCCF8>

# %%
# Multiplying the kernel by a factor of 2 to get the Horizontal Edge Detector Kernel
hor_kernel = 2 * (kernel)
dst = cv2.filter2D(image,-1, hor_kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F8D42FCC550>

# %% [markdown]
# # Blur Kernel

# %%
# Blur Kernel 
kernel = np.float32([(1, 2, 1), (2, 4, 2), (1, 2, 1)])

blur_kernel = (1/64) * kernel

dst = cv2.filter2D(image,-1,blur_kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F8D4175B2E8>

# %%
kernel = np.float32([(1, 2, 1), (2, 4, 2), (1, 2, 1)])

blur_kernel = (1/128) * kernel
                          
dst = cv2.filter2D(image,-1, blur_kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F8D41756320>

# %%
kernel = np.float32([(1, 2, 1), (2, 4, 2), (1, 2, 1)])

blur_kernel = (1/256) * kernel
                          
dst = cv2.filter2D(image,-1, blur_kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F8D4175A358>

# %% [markdown]
# # SHARPEN KERNEL

# %%
kernel = np.float32([(0, -1, 0), (-1, 5, -1), (0, -1, 0)])

sharpen_kernel = 5/4 * kernel
                          
dst = cv2.filter2D(image,-1, sharpen_kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F8D4175A7B8>

# %%
kernel = np.float32([(0, -1, 0), (-1, 5, -1), (0, -1, 0)])

sharpen_kernel = 6/5 * kernel
                          
dst = cv2.filter2D(image,-1, sharpen_kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F8D417567B8>

# %%
kernel = np.float32([(0, -1, 0), (-1, 5, -1), (0, -1, 0)])

sharpen_kernel = 7/6 * kernel
                          
dst = cv2.filter2D(image,-1, sharpen_kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F8D41763860>

# %% [markdown]
# # IDENTITY KERNEL

# %%
kernel = np.float32([(0, 0, 0), (0, 1, 0), (0, 0, 0)])

identity_kernel = kernel
                          
dst = cv2.filter2D(image,-1, identity_kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F8D4175A6D8>

# %% [markdown]
# # 45 Degree Angle Detector

# %%
# https://stackoverflow.com/questions/8547127/how-to-detect-45-degree-edges-in-an-image

kernel = np.float32([(0, 1, 2), (-1, 0, 1), (-2, -1, 0)])

identity_kernel = 1/2 * kernel
                          
dst = cv2.filter2D(image,-1, identity_kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F8D41762940>
